# %%
import numpy as np
from numpy.linalg import norm
import math
import csv
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings
warnings.filterwarnings('ignore', category=PendingDeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
def sim_Jaccard (str1,str2) :
    set1 = set( str1.lower().replace(';',' ').replace(',',' ').replace('.',' ').replace(':',' ').replace('&',' ').
               replace('/',' ').replace('\'',' ').replace('(author)',' ').replace('(joint author)',' ').split() )
    set2 = set( str2.lower().replace(';',' ').replace(',',' ').replace('.',' ').replace(':',' ').replace('&',' ').
               replace('/',' ').replace('\'',' ').replace('(author)',' ').replace('(joint author)',' ').split() )
    return len(set1&set2)/len(set1|set2)

# %%
def sigmoid(x):
    return  1 / ( 1 + math.exp(-x) )

#imp(str1->str2)
def imp_Jaccard (str1,str2) :
    set1 = set( str1.lower().replace(';',' ').replace(',',' ').replace('.',' ').replace(':',' ').replace('&',' ').
               replace('/',' ').replace('\'',' ').replace('(author)',' ').replace('(joint author)',' ').split() )
    set2 = set( str2.lower().replace(';',' ').replace(',',' ').replace('.',' ').replace(':',' ').replace('&',' ').
               replace('/',' ').replace('\'',' ').replace('(author)',' ').replace('(joint author)',' ').split() )
    imp_rate = len(set1&set2)/len(set1)
    return imp_rate-0.5

class TruthFinder(object):
    
    def __init__(self,implication,dampening_factor=0.3,influence_related=0.5,source_col='source',key_col='isbn',ans_col='author'):
        assert(0 < dampening_factor < 1)
        assert(0 <= influence_related <= 1)
        self.implication = implication
        self.dampening_factor = dampening_factor
        self.influence_related = influence_related
        self.source_col = source_col
        self.key_col = key_col
        self.ans_col = ans_col
        
    def train(self,dataframe,max_iterations=10,
              threshold=1e-4,initial_trustworthiness=0.9):
        dataframe["trustworthiness"]=\
            np.ones(len(dataframe.index))*initial_trustworthiness
        dataframe["fact_confidence"] = np.zeros(len(dataframe.index))
        for i in range(max_iterations):
            print('iteration',i)
            t1 = dataframe.drop_duplicates( self.source_col )["trustworthiness"]
            dataframe = self.iteration(dataframe)
            t2 = dataframe.drop_duplicates( self.source_col )["trustworthiness"]
            if self.stop_condition(t1,t2,threshold*len(dataframe)):
                return dataframe
        return dataframe
        
    def iteration(self,df):
        df = self.update_fact_confidence(df)
        df = self.update_website_trustworthiness(df)
        return df
    
    def stop_condition(self,t1,t2,threshold):
        return norm(t2-t1)<threshold
        
    def update_fact_confidence(self,df):
        for object_ in df[ self.key_col ].unique():
            indices = df[ self.key_col ] == object_
            d = df.loc[indices]
            d = self.calculate_confidence(d)
            s = self.adjust_confidence(d)
            df.loc[indices] = self.compute_fact_confidence(d)
        return df
    
    def calculate_confidence(self,df):
        #Eq 3,5
        truthworthiness_score = lambda x: -math.log(1.0-x)
        for i,row in df.iterrows():
            ts = df.loc[df[ self.ans_col ]==row[ self.ans_col ],"trustworthiness"]
            try:
                v = sum(truthworthiness_score(t) for t in ts)
            except ValueError:
                print(i,row)
                print(df.loc[df[self.key_col]==row[self.key_col]])
                
            df.set_value(i,"fact_confidence",v)
        return df
    
    def adjust_confidence(self,df):
        #Eq 6
        update = {}
        for i,row1 in df.iterrows():
            f1 = row1[ self.ans_col ]
            s = 0
            for j,row2 in df.drop_duplicates( self.ans_col ).iterrows():
                f2 = row2[ self.ans_col ]
                if f1==f2:
                    continue
                s += row2["fact_confidence"] * self.implication(f2,f1)
            update[i] = self.influence_related * s + row1["fact_confidence"]
        for i,row1 in df.iterrows():
            df.set_value(i,"fact_confidence",update[i])
        return df
    
    def compute_fact_confidence(self,df):
        #Eq 8
        f = lambda x: sigmoid(self.dampening_factor*x)
        for i,row in df.iterrows():
            df.set_value(i,"fact_confidence",f(row["fact_confidence"]))
        return df
    
    def update_website_trustworthiness(self,df):
        #Eq 1
        for website in df[ self.source_col ].unique():
            indices = df[ self.source_col ]==website
            cs = df.loc[indices,"fact_confidence"]
            df.loc[indices,"trustworthiness"] = sum(cs)/len(cs)
        return df

# %%
dataframe = pd.read_csv( './DataSet/book/golden/claims_golden.txt' , sep='\t' )
finder = TruthFinder(imp_Jaccard,dampening_factor=0.3,influence_related=0.5)
dataframe = finder.train(dataframe)
# Out:
# iteration 0
# iteration 1
# iteration 2
# 1455 source                                                 ER Books
# isbn                                                 0201889544
# name               The C++ Programming Language (Third Edition)
# author                                       Stroustrup, Bjarne
# encode                                                      NaN
# label                                                      True
# trustworthiness                                               1
# fact_confidence                                               1
# Name: 1455, dtype: object
#                                        source        isbn  \
# 1453                             Frugal Media  0201889544
# 1454     Rainbow Bear Books and Miscellaneous  0201889544
# 1455                                 ER Books  0201889544
# 1456                             Sandra Gudac  0201889544
# 1457                               Cobain LLC  0201889544
# 1458                          Cellar of Books  0201889544
# 1459                         BridgeTown Books  0201889544
# 1460                          Powell's  Books  0201889544
# 1461                               xpresstext  0201889544
# 1462                              Bingo Books  0201889544
# 1463                              eCampus.com  0201889544
# 1464                                  Kitabay  0201889544
# 1465                             textbooksNow  0201889544
# 1466                                  Memicky  0201889544
# 1467                              GREAT_TEXTS  0201889544
# 1468                                Indoo.com  0201889544
# 1469                           OPOE-ABE Books  0201889544
# 1470                                  A1Books  0201889544
# 1471                          textbookxdotcom  0201889544
# 1472                                   Caiman  0201889544
# 1473                              Sandy Chong  0201889544
# 1474                        paperbackworld.de  0201889544
# 1475                         Books Down Under  0201889544
# 1476                                 AHA-BUCH  0201889544
# 1477     Versandantiquariat Robert A. Mueller  0201889544
# 1478           Marando.de Versandbuchhandlung  0201889544
# 1479                Morgenstundt Buch & Kunst  0201889544
# 1480                               Bobs Books  0201889544
# 1481                           Mellon's Books  0201889544
# 1482                               TheBookCom  0201889544
# 1483                         Blackwell Online  0201889544
# 1484                       Books2Anywhere.com  0201889544
# 1485                      The Book Depository  0201889544
# 1486  FREE U.S. AIR SHIPPING @ thebookcompany  0201889544
# 1487                        THESAINTBOOKSTORE  0201889544
# 1488                             Quartermelon  0201889544
# 1489                        Revaluation Books  0201889544
# 1490                          Stratford Books  0201889544
# 1491                        Revaluation Books  0201889544
# 1492                               Bobs Books  0201889544
# 1493                        Revaluation Books  0201889544
# 1494                       Limelight Bookshop  0201889544
#
#                                                    name  \
# 1453         The C++ Programming Language (3rd Edition)
# 1454               C ++ Programming Language Third Edit
# 1455       The C++ Programming Language (Third Edition)
# 1456         The C++ Programming Language (3rd Edition)
# 1457  The C++ Programming Language (Special 3rd Edit...
# 1458                       The C++ Programming Language
# 1459  The C++ Programming Language : Language Librar...
# 1460                              C++ Prog Language 3ed
# 1461  The C++ Programming Language (3rd Edition) [Pa...
# 1462              The C++ Programming Language. 3rd ed.
# 1463  The C++ Programming Language : Language Librar...
# 1464                       The C++ Programming Language
# 1465                           C++ Programming Language
# 1466         The C++ Programming Language (3rd Edition)
# 1467  The C++ Programming Language : Language Librar...
# 1468                      C++ Programming Language, The
# 1469                           C++ PROGRAMMING LANGUAGE
# 1470                       The C++ Programming Language
# 1471                       The C++ Programming Language
# 1472                     C++ PROGRAMMING LANGUAGE STILL
# 1473         The C++ Programming Language (3rd Edition)
# 1474                      The C++ Programming Language.
# 1475                       The C++ Programming Language
# 1476                       The C++ Programming Language
# 1477                      The C++ Programming Language.
# 1478                       The C++ Programming Language
# 1479  C++ Programming Language, The: Language Librar...
# 1480                       The C++ Programming Language
# 1481                           C++ PROGRAMMING LANGUAGE
# 1482  The C++ Programming Language : Language Librar...
# 1483                       The C++ Programming Language
# 1484                           C++ Programming Language
# 1485                           C++ Programming Language
# 1486  The C++ Programming Language : Language Librar...
# 1487         The C++ Programming Language (3rd Edition)
# 1488       The C++ Programming Language Still Available
# 1489                       C++ Programming Language The
# 1490       The C++ Programming Language Still Available
# 1491  The C++ Programming Language: Language Library...
# 1492                           C++ Programming Language
# 1493                       The C++ Programming Language
# 1494                           C++ Programming Language
#
#                            author  encode  label  trustworthiness  \
# 1453            Bjarne Stroustrup     NaN   True         0.999787
# 1454           Bjarne Stroudstrup     NaN   True         0.442302
# 1455           Stroustrup, Bjarne     NaN   True         1.000000
# 1456           Stroustrup, Bjarne     NaN   True         1.000000
# 1457            Bjarne Stroustrup     NaN   True         0.999797
# 1458           Stroustrup, Bjarne     NaN   True         1.000000
# 1459           Stroustrup, Bjarne     NaN   True         1.000000
# 1460           Stroustrup, Bjarne     NaN   True         0.849045
# 1461                Not Available     NaN  False         0.000003
# 1462           Stroustrup, Bjarne     NaN   True         0.999950
# 1463           Stroustrup, Bjarne     NaN   True         0.898558
# 1464           Stroustrup, Bjarne     NaN   True         0.996998
# 1465                   Stroustrup     NaN  False         0.282601
# 1466            Bjarne Stroustrup     NaN   True         1.000000
# 1467           Stroustrup, Bjarne     NaN   True         1.000000
# 1468           Stroustrup, Bjarne     NaN   True         0.700649
# 1469                   STROUSTRUP     NaN  False         0.215070
# 1470           Stroustrup, Bjarne     NaN   True         0.948055
# 1471            Bjarne Stroustrup     NaN   True         0.705955
# 1472           Stroustrup, Bjarne     NaN   True         0.840980
# 1473            Bjarne Stroustrup     NaN   True         0.991915
# 1474            Bjarne Stroustrup     NaN   True         0.903835
# 1475                Not Available     NaN  False         0.871597
# 1476            Bjarne Stroustrup     NaN   True         0.967451
# 1477           Stroustrup, Bjarne     NaN   True         0.923931
# 1478            Bjarne Stroustrup     NaN   True         0.986641
# 1479           Stroustrup, Bjarne     NaN   True         0.959969
# 1480                Not Available     NaN  False         0.870564
# 1481           STROUSTRUP, BJARNE     NaN   True         0.758689
# 1484                       Books2Anywhere.com  0201889544
# 1485                      The Book Depository  0201889544
# 1486  FREE U.S. AIR SHIPPING @ thebookcompany  0201889544
# 1487                        THESAINTBOOKSTORE  0201889544
# 1488                             Quartermelon  0201889544
# 1489                        Revaluation Books  0201889544
# 1490                          Stratford Books  0201889544
# 1491                        Revaluation Books  0201889544
# 1492                               Bobs Books  0201889544
# 1493                        Revaluation Books  0201889544
# 1494                       Limelight Bookshop  0201889544
#
#                                                    name  \
# 1453         The C++ Programming Language (3rd Edition)
# 1454               C ++ Programming Language Third Edit
# 1455       The C++ Programming Language (Third Edition)
# 1456         The C++ Programming Language (3rd Edition)
# 1457  The C++ Programming Language (Special 3rd Edit...
# 1458                       The C++ Programming Language
# 1459  The C++ Programming Language : Language Librar...
# 1460                              C++ Prog Language 3ed
# 1461  The C++ Programming Language (3rd Edition) [Pa...
# 1462              The C++ Programming Language. 3rd ed.
# 1463  The C++ Programming Language : Language Librar...
# 1464                       The C++ Programming Language
# 1465                           C++ Programming Language
# 1466         The C++ Programming Language (3rd Edition)
# 1467  The C++ Programming Language : Language Librar...
# 1468                      C++ Programming Language, The
# 1469                           C++ PROGRAMMING LANGUAGE
# 1470                       The C++ Programming Language
# 1471                       The C++ Programming Language
# 1472                     C++ PROGRAMMING LANGUAGE STILL
# 1473         The C++ Programming Language (3rd Edition)
# 1474                      The C++ Programming Language.
# 1475                       The C++ Programming Language
# 1476                       The C++ Programming Language
# 1477                      The C++ Programming Language.
# 1478                       The C++ Programming Language
# 1479  C++ Programming Language, The: Language Librar...
# 1480                       The C++ Programming Language
# 1481                           C++ PROGRAMMING LANGUAGE
# 1482  The C++ Programming Language : Language Librar...
# 1483                       The C++ Programming Language
# 1484                           C++ Programming Language
# 1485                           C++ Programming Language
# 1486  The C++ Programming Language : Language Librar...
# 1487         The C++ Programming Language (3rd Edition)
# 1488       The C++ Programming Language Still Available
# 1489                       C++ Programming Language The
# 1490       The C++ Programming Language Still Available
# 1491  The C++ Programming Language: Language Library...
# 1492                           C++ Programming Language
# 1493                       The C++ Programming Language
# 1494                           C++ Programming Language
#
#                            author  encode  label  trustworthiness  \
# 1453            Bjarne Stroustrup     NaN   True         0.999787
# 1454           Bjarne Stroudstrup     NaN   True         0.442302
# 1455           Stroustrup, Bjarne     NaN   True         1.000000
# 1456           Stroustrup, Bjarne     NaN   True         1.000000
# 1457            Bjarne Stroustrup     NaN   True         0.999797
# 1458           Stroustrup, Bjarne     NaN   True         1.000000
# 1459           Stroustrup, Bjarne     NaN   True         1.000000
# 1460           Stroustrup, Bjarne     NaN   True         0.849045
# 1461                Not Available     NaN  False         0.000003
# 1462           Stroustrup, Bjarne     NaN   True         0.999950
# 1463           Stroustrup, Bjarne     NaN   True         0.898558
# 1464           Stroustrup, Bjarne     NaN   True         0.996998
# 1465                   Stroustrup     NaN  False         0.282601
# 1466            Bjarne Stroustrup     NaN   True         1.000000
# 1467           Stroustrup, Bjarne     NaN   True         1.000000
# 1468           Stroustrup, Bjarne     NaN   True         0.700649
# 1469                   STROUSTRUP     NaN  False         0.215070
# 1469                           OPOE-ABE Books  0201889544
# 1470                                  A1Books  0201889544
# 1471                          textbookxdotcom  0201889544
# 1472                                   Caiman  0201889544
# 1473                              Sandy Chong  0201889544
# 1474                        paperbackworld.de  0201889544
# 1475                         Books Down Under  0201889544
# 1476                                 AHA-BUCH  0201889544
# 1477     Versandantiquariat Robert A. Mueller  0201889544
# 1478           Marando.de Versandbuchhandlung  0201889544
# 1479                Morgenstundt Buch & Kunst  0201889544
# 1480                               Bobs Books  0201889544
# 1481                           Mellon's Books  0201889544
# 1482                               TheBookCom  0201889544
# 1483                         Blackwell Online  0201889544
# 1484                       Books2Anywhere.com  0201889544
# 1485                      The Book Depository  0201889544
# 1486  FREE U.S. AIR SHIPPING @ thebookcompany  0201889544
# 1487                        THESAINTBOOKSTORE  0201889544
# 1488                             Quartermelon  0201889544
# 1489                        Revaluation Books  0201889544
# 1490                          Stratford Books  0201889544
# 1491                        Revaluation Books  0201889544
# 1492                               Bobs Books  0201889544
# 1493                        Revaluation Books  0201889544
# 1494                       Limelight Bookshop  0201889544
#
#                                                    name  \
# 1453         The C++ Programming Language (3rd Edition)
# 1454               C ++ Programming Language Third Edit
# 1455       The C++ Programming Language (Third Edition)
# 1456         The C++ Programming Language (3rd Edition)
# 1457  The C++ Programming Language (Special 3rd Edit...
# 1458                       The C++ Programming Language
# 1459  The C++ Programming Language : Language Librar...
# 1460                              C++ Prog Language 3ed
# 1461  The C++ Programming Language (3rd Edition) [Pa...
# 1462              The C++ Programming Language. 3rd ed.
# 1463  The C++ Programming Language : Language Librar...
# 1464                       The C++ Programming Language
# 1465                           C++ Programming Language
# 1466         The C++ Programming Language (3rd Edition)
# 1467  The C++ Programming Language : Language Librar...
# 1468                      C++ Programming Language, The
# 1469                           C++ PROGRAMMING LANGUAGE
# 1470                       The C++ Programming Language
# 1471                       The C++ Programming Language
# 1472                     C++ PROGRAMMING LANGUAGE STILL
# 1473         The C++ Programming Language (3rd Edition)
# 1474                      The C++ Programming Language.
# 1475                       The C++ Programming Language
# 1476                       The C++ Programming Language
# 1477                      The C++ Programming Language.
# 1478                       The C++ Programming Language
# 1479  C++ Programming Language, The: Language Librar...
# 1480                       The C++ Programming Language
# 1481                           C++ PROGRAMMING LANGUAGE
# 1482  The C++ Programming Language : Language Librar...
# 1483                       The C++ Programming Language
# 1484                           C++ Programming Language
# 1485                           C++ Programming Language
# 1486  The C++ Programming Language : Language Librar...
# 1487         The C++ Programming Language (3rd Edition)
# 1488       The C++ Programming Language Still Available
# 1489                       C++ Programming Language The
# 1490       The C++ Programming Language Still Available
# 1491  The C++ Programming Language: Language Library...
# 1492                           C++ Programming Language
# 1493                       The C++ Programming Language
# 1494                           C++ Programming Language
#
#                            author  encode  label  trustworthiness  \
# 1453            Bjarne Stroustrup     NaN   True         0.999787
# 1454           Bjarne Stroudstrup     NaN   True         0.442302
# 1455           Stroustrup, Bjarne     NaN   True         1.000000
# 1456           Stroustrup, Bjarne     NaN   True         1.000000
# 1457            Bjarne Stroustrup     NaN   True         0.999797
# 1458           Stroustrup, Bjarne     NaN   True         1.000000
# Name: 1459, dtype: object
#                                        source        isbn  \
# 1453                             Frugal Media  0201889544
# 1454     Rainbow Bear Books and Miscellaneous  0201889544
# 1455                                 ER Books  0201889544
# 1456                             Sandra Gudac  0201889544
# 1457                               Cobain LLC  0201889544
# 1458                          Cellar of Books  0201889544
# 1459                         BridgeTown Books  0201889544
# 1460                          Powell's  Books  0201889544
# 1461                               xpresstext  0201889544
# 1462                              Bingo Books  0201889544
# 1463                              eCampus.com  0201889544
# 1464                                  Kitabay  0201889544
# 1465                             textbooksNow  0201889544
# 1466                                  Memicky  0201889544
# 1467                              GREAT_TEXTS  0201889544
# 1468                                Indoo.com  0201889544
# 1469                           OPOE-ABE Books  0201889544
# 1470                                  A1Books  0201889544
# 1471                          textbookxdotcom  0201889544
# 1472                                   Caiman  0201889544
# 1473                              Sandy Chong  0201889544
# 1474                        paperbackworld.de  0201889544
# 1475                         Books Down Under  0201889544
# 1476                                 AHA-BUCH  0201889544
# 1477     Versandantiquariat Robert A. Mueller  0201889544
# 1478           Marando.de Versandbuchhandlung  0201889544
# 1479                Morgenstundt Buch & Kunst  0201889544
# 1480                               Bobs Books  0201889544
# 1481                           Mellon's Books  0201889544
# 1482                               TheBookCom  0201889544
# 1483                         Blackwell Online  0201889544
# 1484                       Books2Anywhere.com  0201889544
# 1485                      The Book Depository  0201889544
# 1486  FREE U.S. AIR SHIPPING @ thebookcompany  0201889544
# 1487                        THESAINTBOOKSTORE  0201889544
# 1488                             Quartermelon  0201889544
# 1489                        Revaluation Books  0201889544
# 1490                          Stratford Books  0201889544
# 1491                        Revaluation Books  0201889544
# 1492                               Bobs Books  0201889544
# 1493                        Revaluation Books  0201889544
# 1494                       Limelight Bookshop  0201889544
#
#                                                    name  \
# 1453         The C++ Programming Language (3rd Edition)
# 1454               C ++ Programming Language Third Edit
# 1455       The C++ Programming Language (Third Edition)
# 1456         The C++ Programming Language (3rd Edition)
# 1457  The C++ Programming Language (Special 3rd Edit...
# 1458                       The C++ Programming Language
# 1459  The C++ Programming Language : Language Librar...
# 1460                              C++ Prog Language 3ed
# 1461  The C++ Programming Language (3rd Edition) [Pa...
# 1462              The C++ Programming Language. 3rd ed.
# 1463  The C++ Programming Language : Language Librar...
# 1464                       The C++ Programming Language
# 1465                           C++ Programming Language
# 1466         The C++ Programming Language (3rd Edition)
# 1467  The C++ Programming Language : Language Librar...
# 1468                      C++ Programming Language, The
# 1469                           C++ PROGRAMMING LANGUAGE
# 1470                       The C++ Programming Language
# 1471                       The C++ Programming Language
# 1472                     C++ PROGRAMMING LANGUAGE STILL
# 1473         The C++ Programming Language (3rd Edition)
# 1474                      The C++ Programming Language.
# 1475                       The C++ Programming Language
# 1476                       The C++ Programming Language
# 1477                      The C++ Programming Language.
# 1478                       The C++ Programming Language
# 1479  C++ Programming Language, The: Language Librar...
# 1480                       The C++ Programming Language
# 1481                           C++ PROGRAMMING LANGUAGE
# 1482  The C++ Programming Language : Language Librar...
# 1483                       The C++ Programming Language
# 1484                           C++ Programming Language
# 1485                           C++ Programming Language
# 1486  The C++ Programming Language : Language Librar...
# 1471                       The C++ Programming Language
# 1472                     C++ PROGRAMMING LANGUAGE STILL
# 1473         The C++ Programming Language (3rd Edition)
# 1474                      The C++ Programming Language.
# 1475                       The C++ Programming Language
# 1476                       The C++ Programming Language
# 1477                      The C++ Programming Language.
# 1478                       The C++ Programming Language
# 1479  C++ Programming Language, The: Language Librar...
# 1480                       The C++ Programming Language
# 1481                           C++ PROGRAMMING LANGUAGE
# 1482  The C++ Programming Language : Language Librar...
# 1483                       The C++ Programming Language
# 1484                           C++ Programming Language
# 1485                           C++ Programming Language
# 1486  The C++ Programming Language : Language Librar...
# 1487         The C++ Programming Language (3rd Edition)
# 1488       The C++ Programming Language Still Available
# 1489                       C++ Programming Language The
# 1490       The C++ Programming Language Still Available
# 1491  The C++ Programming Language: Language Library...
# 1492                           C++ Programming Language
# 1493                       The C++ Programming Language
# 1494                           C++ Programming Language
#
#                            author  encode  label  trustworthiness  \
# 1453            Bjarne Stroustrup     NaN   True         0.999787
# 1454           Bjarne Stroudstrup     NaN   True         0.442302
# 1455           Stroustrup, Bjarne     NaN   True         1.000000
# 1456           Stroustrup, Bjarne     NaN   True         1.000000
# 1457            Bjarne Stroustrup     NaN   True         0.999797
# 1458           Stroustrup, Bjarne     NaN   True         1.000000
# 1459           Stroustrup, Bjarne     NaN   True         1.000000
# 1460           Stroustrup, Bjarne     NaN   True         0.849045
# 1461                Not Available     NaN  False         0.000003
# 1462           Stroustrup, Bjarne     NaN   True         0.999950
# 1463           Stroustrup, Bjarne     NaN   True         0.898558
# 1464           Stroustrup, Bjarne     NaN   True         0.996998
# 1465                   Stroustrup     NaN  False         0.282601
# 1466            Bjarne Stroustrup     NaN   True         1.000000
# 1467           Stroustrup, Bjarne     NaN   True         1.000000
# 1468           Stroustrup, Bjarne     NaN   True         0.700649
# 1469                   STROUSTRUP     NaN  False         0.215070
# 1470           Stroustrup, Bjarne     NaN   True         0.948055
# 1471            Bjarne Stroustrup     NaN   True         0.705955
# 1472           Stroustrup, Bjarne     NaN   True         0.840980
# 1473            Bjarne Stroustrup     NaN   True         0.991915
# 1474            Bjarne Stroustrup     NaN   True         0.903835
# 1475                Not Available     NaN  False         0.871597
# 1476            Bjarne Stroustrup     NaN   True         0.967451
# 1477           Stroustrup, Bjarne     NaN   True         0.923931
# 1478            Bjarne Stroustrup     NaN   True         0.986641
# 1479           Stroustrup, Bjarne     NaN   True         0.959969
# 1480                Not Available     NaN  False         0.870564
# 1481           STROUSTRUP, BJARNE     NaN   True         0.758689
# 1482           Stroustrup, Bjarne     NaN   True         0.885538
# 1483            Bjarne Stroustrup     NaN   True         0.975025
# 1484           Stroustrup, Bjarne     NaN   True         0.993047
# 1485            Bjarne Stroustrup     NaN   True         0.693593
# 1486           Stroustrup, Bjarne     NaN   True         0.853333
# 1487           Stroustrup, Bjarne     NaN   True         0.998855
# 1488  Stroustrup, Bjarne (Author)     NaN  False         0.978103
# 1489           Stroustrup, Bjarne     NaN   True         0.961150
# 1490  Stroustrup, Bjarne (Author)     NaN  False         0.985909
# 1491            Bjarne Stroustrup     NaN   True         0.961150
# 1492            Bjarne Stroustrup     NaN   True         0.870564
# 1493           Stroustrup, Bjarne     NaN   True         0.961150
# 1494           Stroustrup, Bjarne     NaN   True         0.851963
#
#       fact_confidence
# 1453        67.704473
# 1454         0.583938
# 1455         0.583938
# 1456         0.583938
# 1457        67.704473
# 1458        67.704473
# 1459        67.704473
# 1460         1.000000
# 1461         0.000003
# 1462         1.000000
# 1463         1.000000
# 1464         1.000000
# 1465         0.463111
# 1466         1.000000
# 1467         1.000000
# 1468         1.000000
# 1469         0.455610
# 1470         1.000000
# 1471         1.000000
# 1472         1.000000
# 1473         1.000000
# 1474         1.000000
# 1475         0.000003
# 1476         1.000000
# 1477         1.000000
# 1478         1.000000
# 1479         1.000000
# 1480         0.000003
# 1481         0.999999
# 1482         1.000000
# ...
# 1490                          Stratford Books  0201889544
# 1491                        Revaluation Books  0201889544
# 1492                               Bobs Books  0201889544
# 1493                        Revaluation Books  0201889544
# 1494                       Limelight Bookshop  0201889544
#
#                                                    name  \
# 1453         The C++ Programming Language (3rd Edition)
# 1454               C ++ Programming Language Third Edit
# 1455       The C++ Programming Language (Third Edition)
# 1456         The C++ Programming Language (3rd Edition)
# 1457  The C++ Programming Language (Special 3rd Edit...
# 1458                       The C++ Programming Language
# 1459  The C++ Programming Language : Language Librar...
# 1460                              C++ Prog Language 3ed
# 1461  The C++ Programming Language (3rd Edition) [Pa...
# 1462              The C++ Programming Language. 3rd ed.
# 1463  The C++ Programming Language : Language Librar...
# 1464                       The C++ Programming Language
# 1465                           C++ Programming Language
# 1466         The C++ Programming Language (3rd Edition)
# 1467  The C++ Programming Language : Language Librar...
# 1468                      C++ Programming Language, The
# 1469                           C++ PROGRAMMING LANGUAGE
# 1470                       The C++ Programming Language
# 1471                       The C++ Programming Language
# 1472                     C++ PROGRAMMING LANGUAGE STILL
# 1473         The C++ Programming Language (3rd Edition)
# 1474                      The C++ Programming Language.
# 1475                       The C++ Programming Language
# 1476                       The C++ Programming Language
# 1477                      The C++ Programming Language.
# 1478                       The C++ Programming Language
# 1479  C++ Programming Language, The: Language Librar...
# 1480                       The C++ Programming Language
# 1481                           C++ PROGRAMMING LANGUAGE
# 1482  The C++ Programming Language : Language Librar...
# 1483                       The C++ Programming Language
# 1484                           C++ Programming Language
# 1485                           C++ Programming Language
# 1486  The C++ Programming Language : Language Librar...
# 1487         The C++ Programming Language (3rd Edition)
# 1488       The C++ Programming Language Still Available
# 1489                       C++ Programming Language The
# 1490       The C++ Programming Language Still Available
# 1491  The C++ Programming Language: Language Library...
# 1492                           C++ Programming Language
# 1493                       The C++ Programming Language
# 1494                           C++ Programming Language
#
#                            author  encode  label  trustworthiness  \
# 1453            Bjarne Stroustrup     NaN   True         0.999787
# 1454           Bjarne Stroudstrup     NaN   True         0.442302
# 1455           Stroustrup, Bjarne     NaN   True         1.000000
# 1456           Stroustrup, Bjarne     NaN   True         1.000000
# 1457            Bjarne Stroustrup     NaN   True         0.999797
# 1458           Stroustrup, Bjarne     NaN   True         1.000000
# 1459           Stroustrup, Bjarne     NaN   True         1.000000
# 1204                           eCampus.com  0321228103
# 1205                            Orca Books  0321228103
# 1206                             Indoo.com  0321228103
# 1207                                Caiman  0321228103
# 1208                       textbookxdotcom  0321228103
# 1209                               A1Books  0321228103
# 1210                      Paperbackshop-US  0321228103
# 1211                        AlphaCraze.com  0321228103
# 1212                       Annex Books Inc  0321228103
# 1213                        OPOE-ABE Books  0321228103
# 1214                         Players Quest  0321228103
# 1215                       Striped Ostrich  0321228103
# 1216                     Kayleighbug Books  0321228103
# 1217                           Kayleighbug  0321228103
# 1218                         Papamedia.com  0321228103
# 1219                           Odeon Books  0321228103
# 1220                       Powell's  Books  0321228103
# 1221                       Powell's  Books  0321228103
# 1222       Englishbookservice.com GTI GmbH  0321228103
# 1223                     paperbackworld.de  0321228103
# 1224                          Browns Books  0321228103
# 1225        Marando.de Versandbuchhandlung  0321228103
# 1226                              AHA-BUCH  0321228103
# 1227             Morgenstundt Buch & Kunst  0321228103
# 1228  Versandantiquariat Robert A. Mueller  0321228103
# 1229                     THESAINTBOOKSTORE  0321228103
# 1230                     Revaluation Books  0321228103
# 1231                   The Book Depository  0321228103
# 1232                     Revaluation Books  0321228103
# 1233                         Gunter Koppon  0321228103
# 1234                          Gunars Store  0321228103
# 1235                            Alinonline  0321228103
# 1236                    Limelight Bookshop  0321228103
# 1237                         MildredsBooks  0321228103
#
#                                                    name        author  encode  \
# 1203  Open Source .NET Development: Programming With...  Nantz, Brian     NaN
# 1204  Open Source .NET Development: Programming With...  Nantz, Brian     NaN
# 1205  Open SourceNET Development: Programming With N...  Nantz, Brian     NaN
# 1206  Open SourceNET Development: Programming with N...  Nantz, Brian     NaN
# 1207                        OPEN SOURCE NET DEVELOPMENT  Nantz, Brian     NaN
# 1208  Open SourceNET Development Programming With Na...   Brian Nantz     NaN
# 1209  Open Source .NET Development: Programming with...  Nantz, Brian     NaN
# 1210                         Open Sourcenet Development  Nantz, Brian     NaN
# 1211  Open Source .NET Development: Programming with...  Nantz, Brian     NaN
# 1212  Open Source .NET Development: Programming with...  Nantz, Brian     NaN
# 1213                   OPEN SOURCE.NET DEVELOPMENT-W/CD         NANTZ     NaN
# 1214  Open Source .NET Development : Programming wit...   Brian Nantz     NaN
# 1215  Open Source .net Development : Programming Wit...  Nantz, Brian     NaN
# 1216  Open Source .NET Development: Programming with...  Nantz, Brian     NaN
# 1217  Open Source .NET Development: Programming with...  Nantz, Brian     NaN
# 1218  Open SourceNET Development : Programming with ...   Brian Nantz     NaN
# 1219  Open Source .NET Development: Programming with...   Brian Nantz     NaN
# 1220  Open Source .net Development: Programming With...  Nantz, Brian     NaN
# 1221           Open Source .net Development Prog With N  Nantz, Brian     NaN
# 1222  Open Source .Net Development: Programming with...  Nantz, Brian     NaN
# 1223                       Open Source .Net Development   Brian Nantz     NaN
# 1224                         Open SourceNet Development  Nantz, Brian     NaN
# 1225              Open SourceNET Development, w. CD-ROM   Brian Nantz     NaN
# 1226              Open SourceNET Development, w. CD-ROM   Brian Nantz     NaN
# 1227  Open Source .Net Development: Programming with...  Nantz, Brian     NaN
# 1228  Open SourceNet Development Programming with NA...  Nantz, Brian     NaN
# 1229  Open Source .NET Development: Programming with...  Nantz, Brian     NaN
# 1230  Open SourceNET Development Programming With Na...  Nantz, Brian     NaN
# 1231                         Open SourceNet Development   Brian Nantz     NaN
# 1232  Open SourceNET Development:Programming with NA...  Nantz, Brian     NaN
# 1233  Open Source .NET Development: Programming with...   Nantz Brian     NaN
# 1234  Open Source .NET Development: Programming with...   Nantz Brian     NaN
# 1235  Open Source .NET Development: Programming With...  Nantz, Brian     NaN
# 1236  Open Source .NET Development: Programming with...  Nantz, Brian     NaN
# 1237  Open SourceNET Development : Programming with ...   Brian Nantz     NaN
#
#       label  trustworthiness  fact_confidence
# 1203   True         1.000000         1.000000
# 1204   True         0.900131         1.000000
# 1205   True         1.000000         1.000000
# 1206   True         0.684061         1.000000
# 1207   True         0.827076         1.000000
# 1208   True         0.700529         1.000000
# 1209   True         0.948099         1.000000
# 1210   True         0.949699         1.000000
# 1211   True         0.999825         1.000000
# 1212   True         0.998859         1.000000
# 1213  False         0.169522         0.518154
# 1214   True         0.997652         1.000000
# 1215   True         0.994552         1.000000
# 1216   True         0.999961         1.000000
# 1217   True         0.999961         1.000000
# 1218   True         0.868663         1.000000
# 1219   True         0.998988         1.000000
# 1220   True         0.827287         1.000000
# 1221   True         0.827287         1.000000
# 1222   True         0.950583         1.000000
# 1223   True         0.901943         1.000000
# 1224   True         0.858920         1.000000
# 1225   True         0.989981         1.000000
# 1226   True         0.969505         1.000000
# 1227   True         0.955585         1.000000
# 1228   True         0.921238         1.000000
# 1229   True         0.999343         1.000000
# 1230   True         0.959399         1.000000
# 1231   True         0.665847         1.000000
# 1232   True         0.959399         1.000000
# 1233   True         0.735685         0.999998
# 1234   True         0.688993         0.999998
# 1235   True         0.991803         1.000000
# 1236   True         0.835604         1.000000
# 1237   True         0.999680         1.000000
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-42-37984a275e72> in <module>()
#       1 dataframe = pd.read_csv( './DataSet/book/golden/claims_golden.txt' , sep='\t' )
#       2 finder = TruthFinder(imp_Jaccard,dampening_factor=0.3,influence_related=0.5)
# ----> 3 dataframe = finder.train(dataframe)
#
# <ipython-input-41-2d143eb71043> in train(self, dataframe, max_iterations, threshold, initial_trustworthiness)
#      30             print('iteration',i)
#      31             t1 = dataframe.drop_duplicates( self.source_col )["trustworthiness"]
# ---> 32             dataframe = self.iteration(dataframe)
#      33             t2 = dataframe.drop_duplicates( self.source_col )["trustworthiness"]
#      34             if self.stop_condition(t1,t2,threshold*len(dataframe)):
#
# <ipython-input-41-2d143eb71043> in iteration(self, df)
#      37
#      38     def iteration(self,df):
# ---> 39         df = self.update_fact_confidence(df)
#      40         df = self.update_website_trustworthiness(df)
#      41         return df
#
# <ipython-input-41-2d143eb71043> in update_fact_confidence(self, df)
#      48             indices = df[ self.key_col ] == object_
#      49             d = df.loc[indices]
# ---> 50             d = self.calculate_confidence(d)
#      51             s = self.adjust_confidence(d)
#      52             df.loc[indices] = self.compute_fact_confidence(d)
#
# <ipython-input-41-2d143eb71043> in calculate_confidence(self, df)
#      64                 print(df.loc[df[self.key_col]==row[self.key_col]])
#      65
# ---> 66             df.set_value(i,"fact_confidence",v)
#      67         return df
#      68
#
# UnboundLocalError: local variable 'v' referenced before assignment

# %%
#1.一些文章中提到答案完全一样的问题对于提升结果没有帮助
#2.存在一些fact_confidence变为1的情况，可能是同一问题下的答案同质化
#3.暂且搁置该段代码

def RemoveUnhelpfulRows(df,key_col='isbn',ans_col='author'):
    i = 0
    for isbn in df[key_col].unique():
        indices = df[key_col]==isbn
        if len(df.loc[indices][ans_col].unique())==1:
            df.drop(index=df.loc[indices].index,inplace=True)
    return df
df_t = RemoveUnhelpfulRows(dataframe)

# %%
def PickHighest(df,indexK='isbn',answer='author',weight='fact_confidence'):
    df_ph = pd.DataFrame(columns=[indexK,answer])
    for indexV in df[indexK].unique():
        df_slice = df[ df[indexK]==indexV ]
        df_slice = df_slice.sort_values( by=weight, ascending=False )
        df_ph = df_ph.append({indexK:df_slice.iloc[0][indexK],answer:df_slice.iloc[0][answer]},ignore_index=True)
    return df_ph

# %%
df_ph = PickHighest(dataframe)
df_ph.set_index('isbn',inplace=True)
label = pd.read_csv('./DataSet/book/book_golden.txt',sep='\t',low_memory=False,names=['isbn','author'],header=None,index_col=0)
#TruthFinder_result.to_csv( './DataSet/vldbBook/TruthFinderResult.txt' , sep='\t' , index=False )

# %%
JudgeAccu(label,df_ph)
# Out:
# Dennis Suhanovs, Press Certification, Certification Press vs suhanovs, dennis ;
# By (author) Hoos, Holger H. By (author) St&uuml;tzle, Thomas vs hoos, holger h.;   stutzle, thomas;
# John Strassner vs strassner, john c.;
# David B. Makofske, Kevin C. Almeroth vs makofske, david ;  almeroth, kevin ;
# Edited by Lacroix, Zo&eacute; Edited by Critchlow, Terence vs lacroix, zoe ;  critchlow, terence;
# Loshin, Peter vs loshin, pete ;
# Puder, Arno; R&ouml;mer, Kay; Pilhofer, Frank vs puder, arno ;  romer, kay ;  pilhofer, frank ;
# By (author) Eberhart, Russell C. By (author) Shi, Yuhui By (author) Kennedy, James vs kennedy, james ;  eberhart, russell c.;
# Edited by Jones, Karen Sparck Edited by Willett, Peter vs jones, karen sparck;  willett, peter ;
# By (author) Duffy, Michael D vs duffy, michael d.;
# Etzel, Michael vs etzel, michael ;  dickinson, karen ;
# Guy Steele vs steele, guy l.;
# Shaw, Paul vs shaw, paul d.;
# By (author) McManus, John vs mcmanus, john ;
# McManus, Jeffrey P.; Goldstein, Jackie; Price, Kevin T. vs mcmanus, jeffrey p.;  goldstein, jackie ;
# Parallel Cfd 2000 Conference (2000 Trondheim, Norway)/ Kvamsdal, T. (EDT)/ Andersson, H. I. (EDT)/ Pettersen, B. (EDT)/ Ecer, Akin (EDT)/ Periaux, J. (EDT)/ Satofuka, N. (EDT)/ Fox, P. (EDT)/ Jenssen, C. B. (EDT)/ Jenssen, C. B. vs jenssen, c. b.;  kvamdal, t. ;  andersson, h. i.;  Ecer, A.;  Periaux, J.;  Satofuka, N.;  Fox, P.;
# Hornick, Mark F.; Marcad&eacute;, Erik; Venkayala, Sunil vs hornick, mark f.;  marcade, erik ;  venkayala, sunil ;
# 0.9294113756613755

# %%
def MV(df,indexK='isbn',answer='author',withWeight=False,weight='confidence'):
    df_mv = pd.DataFrame(columns=[indexK,answer])
    for indexV in df[indexK].unique():
        data_slice = df[df[indexK]==indexV]
        vote_dict = {}
        for index,row in data_slice.iterrows():
            flag = False
            for key in vote_dict.keys():
                if ( sim_Jaccard(key,row[answer])>=0.8 ):
                    flag = True
                    if(not withWeight):
                        vote_dict[key] += 1
                    else:
                        vote_dict[key] += float(row[weight])
                    break
            if (not flag):
                if(not withWeight):
                    vote_dict[row[answer]] = 1
                else:
                    vote_dict[row[answer]] = float(row[weight])
        vote_list = sorted(vote_dict.items(), key=lambda d:d[1],reverse=True)
        #print({indexK:indexV,answer:vote_list[0][0]})
        df_mv = df_mv.append({indexK:indexV,answer:vote_list[0][0]},ignore_index=True)
    return df_mv

# %%
df_mv = MV(dataframe,withWeight=True,weight='fact_confidence')
df_mv.set_index('isbn',inplace=True)
#df_mv.to_csv( './DataSet/vldbBook/TruthFinderResult_mv.txt' , sep='\t' , index=False )

# %%
JudgeAccu(label,df_mv)
# Out:
# Conklin, Art; Davis, Roger; Williams, Dwayne; Cothren, Chuck vs conklin, wm. arthur;  white, gregory b.;  cothren, chuck ;  williams, dwayne ;  davis, roger l.;
# Dennis Suhanovs, Press Certification, Certification Press vs suhanovs, dennis ;
# White, Gregory B. vs white, gregory ;
# Meadors, Todd; Schmidt, Cheryl Ann vs meadors, todd ;  schmidt, cheryl a.;
# Hoos, Holger vs hoos, holger h.;   stutzle, thomas;
# John Strassner vs strassner, john c.;
# Zoe Lacroix vs lacroix, zoe ;  critchlow, terence;
# Loshin, Peter vs loshin, pete ;
# Eberhart, Russell vs kennedy, james ;  eberhart, russell c.;
# Edited by Jones, Karen Sparck Edited by Willett, Peter vs jones, karen sparck;  willett, peter ;
# Erbschloe vs erbschloe, michael ;
# Etzel, Michael vs etzel, michael ;  dickinson, karen ;
# Guy Steele vs steele, guy l.;
# Shaw, Paul vs shaw, paul d.;
# Jenssen, C. B. vs jenssen, c. b.;  kvamdal, t. ;  andersson, h. i.;  Ecer, A.;  Periaux, J.;  Satofuka, N.;  Fox, P.;
# Dowd, Mark; McDonald, John vs dowd, mark ;  mcdonald, john ;  schuh, justin ;
# Hornick, Mark F. vs hornick, mark f.;  marcade, erik ;  venkayala, sunil ;
# Moore vs moore, martin ;  hancock, steven ;
# 0.9121369047619048

# %%
def JudgeAccu(label,pred,pred_col='author'):
    score = 0
    for index,row in pred.iterrows():
        if not(index in label.index):
            print(index,'no answer')
            score += 0 
        elif sim_Jaccard(row[pred_col],label.loc[index][pred_col])>=0.8:
            score +=1
        else:
            print(row[pred_col],"vs",label.loc[index][pred_col])
            score += sim_Jaccard(row[pred_col],label.loc[index][pred_col])
    return score/len(pred)

# %%
label = pd.read_csv('./DataSet/vldbBook/book_truth.txt',sep='\t',low_memory=False,index_col=0)
label.rename(columns={'isbn_10':'isbn','authors_truth':'author'},inplace=True)
pred = pd.read_csv('./DataSet/vldbBook/TruthFinderResult_mv.txt',sep='\t',low_memory=False,index_col=0)
print(JudgeAccu(label,pred))
